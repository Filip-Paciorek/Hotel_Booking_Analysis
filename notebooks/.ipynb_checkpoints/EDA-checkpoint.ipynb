# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### import the database

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/hotel_bookings.csv')

# %% [markdown]
# ### First I'll look at basic data characteristics to see what im working with exactly

# %%
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Now I can see that there is most likely problems with ADR since its negative at its lowest which it shouldn't be

# %% [markdown]
# ### Check for nulls

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# ### Right now I know that children and probably country have some truly missing data because agent and company are designed in a way where nulls are put there on purpose

# %% [markdown]
# ### It's also worth checking to see if there are ghost records with no adults, as children can't get a room by themselves

# %%
df[df['adults'] < 0]
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, company, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date]
# Index: []
#
# [0 rows x 32 columns]

# %% [markdown]
# ### Now I'm checking if there are ghost records with no nights spent at the hotel

# %%
df['total_nights'] = (df['stays_in_weekend_nights'] + df['stays_in_week_nights'])
print(df[df['total_nights']== 0] )
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 167     Resort Hotel            0        111               2015
# 168     Resort Hotel            0          0               2015
# 196     Resort Hotel            0          8               2015
# ...              ...          ...        ...                ...
# 115483    City Hotel            0         15               2017
# 117701    City Hotel            0          0               2017
# 118029    City Hotel            0          0               2017
# 118631    City Hotel            0         78               2017
# 118963    City Hotel            0          1               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ## Basic analysis summary:

# %% [markdown]
# ### I can see that the data is mostly clean, also its clearly visible that many of the columns have no use in a general data analysis and are more useful for model training or a specific target.

# %% [markdown]
# ### To continue with analysing this data, ill implement simple fixes here regarding data I deem broken (children,country,adr)

# %%
df[df['country'].isna()]['country']
df_clean = df[df['country'].notna()]
df_clean.shape

# %%
print(df['children'].unique())
df_clean = df_clean[df_clean['children'].notna()]
df_clean.shape

# %%
df[df['adr'] < 0]

# %%
df_clean = df_clean[df_clean['adr']>=0]
df_clean.shape

# %% [markdown]
# ## Getting rid of the noise

# %% [markdown]
# ### Another important thing to consider is what data is just noise for us, since I'm making a detailed overview without a specific point to focus on, I've decided to get rid of: agent,company,reservation_status,reservation_status_date,arrival_date_week_number,arrival_date_day_of_month,deposit_type,assigned_room_type,booking_changes,stays_in_weekend_nights,stays_in_week_nights
